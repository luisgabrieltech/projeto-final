# %%
import pandas as pd

# %%
df = pd.read_csv("../data/processed/acidentes_tratado.csv")

# %%
df["km"] = df["km"].str.replace(",", ".").astype(float)

# %%
print(df.shape) 
print(df.dtypes) 
print(df.isnull().sum())
df.head()
# Out:
# (22499, 11)
# data_inversa               object
# horario                    object
# br                          int64
# km                        float64
# municipio                  object
# uf                         object
# tipo_acidente              object
# causa_acidente             object
# condicao_metereologica     object
# data                       object
# hora                        int64
# dtype: object
# data_inversa              0
# horario                   0
# br                        0
# km                        0
# municipio                 0
# uf                        0
# tipo_acidente             0
# causa_acidente            0
# condicao_metereologica    0
# data                      0
# hora                      0
# dtype: int64
#   data_inversa   horario   br     km              municipio  uf  \
# 0   2025-01-01  06:20:00  116  225.0              GUARULHOS  SP
# 1   2025-01-01  07:50:00  116  546.2              PENAFORTE  CE
# ...
